# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense 
from keras.optimizers import gradient_descent_v2 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
plt.figure(figsize=(9, 7))
x=np.linspace(-5,5,200)
y=5*x+np.random.normal(0,5,x.shape)
plt.xlabel('x') 
plt.ylabel('y') 
plt.scatter(x,y)

# %%
model = keras.Sequential()
model.add(tf.keras.layers.Dense(1,input_shape=(1,)))
model.summary()
model.compile(optimizer='adam',loss='mse')
history=model.fit(x,y,epochs=1000)
history_df = pd.DataFrame(history.history)
plt.title("Loss")
history_df['loss'].plot();
plt.figure(figsize=(9, 7))
plt.xlabel('x') 
plt.ylabel('y') 
plt.scatter(x,y)
plt.plot(x,model.predict(x),color="black")
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1)                 2
#
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# 7/7 [==============================] - 0s 3ms/step - loss: 195.7024
# Epoch 2/1000
# 7/7 [==============================] - 0s 1ms/step - loss: 195.1852
# Epoch 3/1000
# 7/7 [==============================] - 0s 1ms/step - loss: 194.6691
# Epoch 4/1000
# 7/7 [==============================] - 0s 1ms/step - loss: 194.1558
# Epoch 5/1000
# 7/7 [==============================] - 0s 1ms/step - loss: 193.6470
# Epoch 6/1000
# 7/7 [==============================] - 0s 1ms/step - loss: 193.1135
# Epoch 7/1000
# 7/7 [==============================] - 0s 1ms/step - loss: 192.6028
# Epoch 8/1000
# ...

# %%
x_data = np.linspace(-0.75,0.75,400)
noise = np.random.normal(0,0.05,x_data.shape)
y_data = x_data**2+ x_data**3+noise;
plt.scatter(x_data,y_data)
plt.show() 

model = Sequential()
model.add(tf.keras.layers.Dense(1,input_shape=(1,))) #inputlayer
model.add(Dense(units=10,input_dim=1,activation='tanh'))  #hidden layer
model.add(Dense(units=15,input_dim=1,activation='tanh'))  #hidden layer
model.add(Dense(units=10,input_dim=1,activation='tanh'))  #hidden layer
model.add(Dense(units=1,activation='tanh'))  #output layer
model.summary()

sgd=gradient_descent_v2.SGD(lr=0.2) 
model.compile(optimizer='adam',loss = 'mse')
model.fit(x_data,y_data,epochs=1000)
history_df = pd.DataFrame(history.history)
plt.title("Loss")
history_df['loss'].plot();
#for step in range(7000):
    #cost = model.train_on_batch(x_data,y_data)
    #if step%1000==0:
        #print('cost:',cost)
y_pred = model.predict(x_data)
plt.figure(figsize=(9, 7)) 
plt.scatter(x_data,y_data)
plt.plot(x_data,y_pred,'r',linewidth=3)
plt.show()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_1 (Dense)             (None, 1)                 2
#
#  dense_2 (Dense)             (None, 10)                20
#
#  dense_3 (Dense)             (None, 15)                165
#
#  dense_4 (Dense)             (None, 10)                160
#
#  dense_5 (Dense)             (None, 1)                 11
#
# ...
# Total params: 358
# Trainable params: 358
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/1000
# C:\Users\Chuxu\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\gradient_descent.py:108: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0610
# Epoch 2/1000
# 13/13 [==============================] - 0s 1ms/step - loss: 0.0438
# ...
